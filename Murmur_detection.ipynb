# %% [markdown]
# Import Libraries needed

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Fetch training data

# %%
murmur_data = pd.read_csv('training_data.csv')

murmur_data.head()
# Out:
#    Patient ID Recording locations:    Age     Sex  Height  Weight  \
# 0        2530          AV+PV+TV+MV  Child  Female    98.0    15.9
# 1        9979          AV+PV+TV+MV  Child  Female   103.0    13.1
# 2        9983          AV+PV+TV+MV  Child    Male   115.0    19.1
# 3       13918          AV+PV+TV+MV  Child    Male    98.0    15.9
# 4       14241          AV+PV+TV+MV  Child    Male    87.0    11.2
#
#    Pregnancy status   Murmur Murmur locations Most audible location  ...  \
# 0             False   Absent              NaN                   NaN  ...
# 1             False  Present      AV+MV+PV+TV                    TV  ...
# 2             False  Unknown              NaN                   NaN  ...
# 3             False  Present               TV                    TV  ...
# 4             False  Present      AV+MV+PV+TV                    PV  ...
#
#   Systolic murmur pitch Systolic murmur quality Diastolic murmur timing  \
# ...

# %%
murmur_data.drop("Patient ID", axis=1, inplace=True)
murmur_data.drop("Campaign", axis=1, inplace=True)
murmur_data.drop("Additional ID", axis=1, inplace=True)

sex = pd.get_dummies(murmur_data['Sex'], drop_first=True)
pregnancy_status = murmur_data['Pregnancy status'].astype(int)

murmur_data.drop(['Sex', 'Pregnancy status'], axis=1, inplace=True)
murmur_data = pd.concat([murmur_data, sex, pregnancy_status], axis=1)

murmur_data.head()
# Out:
#   Recording locations:    Age  Height  Weight   Murmur Murmur locations  \
# 0          AV+PV+TV+MV  Child    98.0    15.9   Absent              NaN
# 1          AV+PV+TV+MV  Child   103.0    13.1  Present      AV+MV+PV+TV
# 2          AV+PV+TV+MV  Child   115.0    19.1  Unknown              NaN
# 3          AV+PV+TV+MV  Child    98.0    15.9  Present               TV
# 4          AV+PV+TV+MV  Child    87.0    11.2  Present      AV+MV+PV+TV
#
#   Most audible location Systolic murmur timing Systolic murmur shape  \
# 0                   NaN                    NaN                   NaN
# 1                    TV           Holosystolic               Diamond
# 2                   NaN                    NaN                   NaN
# 3                    TV           Holosystolic               Plateau
# 4                    PV         Early-systolic               Plateau
#
#   Systolic murmur grading Systolic murmur pitch Systolic murmur quality  \
# ...
